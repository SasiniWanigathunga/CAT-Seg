# %%
# ADE20K 150 classes / model_large

ade150_catseg = {'sem_seg': {'mIoU': 37.79342244034116, 'fwIoU': 64.72120423599192, 'IoU-wall': 73.88573431296095, 'BoundaryIoU-wall': 73.86020610163398, 'min(IoU, B-Iou)-wall': 73.86020610163398, 'IoU-building': 65.89399131903197, 'BoundaryIoU-building': 8.670766838341146, 'min(IoU, B-Iou)-building': 8.670766838341146, 'IoU-sky': 92.89689539733995, 'BoundaryIoU-sky': 0.0, 'min(IoU, B-Iou)-sky': 0.0, 'IoU-floor': 78.55686841523557, 'BoundaryIoU-floor': 0.0, 'min(IoU, B-Iou)-floor': 0.0, 'IoU-tree': 71.60351912375562, 'BoundaryIoU-tree': 0.0, 'min(IoU, B-Iou)-tree': 0.0, 'IoU-ceiling': 81.2525033336575, 'BoundaryIoU-ceiling': 0.0, 'min(IoU, B-Iou)-ceiling': 0.0, 'IoU-road': 78.38213438220535, 'BoundaryIoU-road': 0.0, 'min(IoU, B-Iou)-road': 0.0, 'IoU-bed ': 81.36872274636, 'BoundaryIoU-bed ': 0.0, 'min(IoU, B-Iou)-bed ': 0.0, 'IoU-windowpane': 50.12541745598191, 'BoundaryIoU-windowpane': 0.0, 'min(IoU, B-Iou)-windowpane': 0.0, 'IoU-grass': 62.35558707830558, 'BoundaryIoU-grass': 0.0, 'min(IoU, B-Iou)-grass': 0.0, 'IoU-cabinet': 58.58584167601569, 'BoundaryIoU-cabinet': 0.0, 'min(IoU, B-Iou)-cabinet': 0.0, 'IoU-sidewalk': 62.188678052633406, 'BoundaryIoU-sidewalk': 0.0, 'min(IoU, B-Iou)-sidewalk': 0.0, 'IoU-person': 82.25816334566588, 'BoundaryIoU-person': 0.0, 'min(IoU, B-Iou)-person': 0.0, 'IoU-earth': 4.730099122735162, 'BoundaryIoU-earth': 0.0, 'min(IoU, B-Iou)-earth': 0.0, 'IoU-door': 44.59167544241557, 'BoundaryIoU-door': 0.0, 'min(IoU, B-Iou)-door': 0.0, 'IoU-table': 44.155954679089746, 'BoundaryIoU-table': 0.0, 'min(IoU, B-Iou)-table': 0.0, 'IoU-mountain': 51.64682221146323, 'BoundaryIoU-mountain': 0.0, 'min(IoU, B-Iou)-mountain': 0.0, 'IoU-plant': 45.01738794034912, 'BoundaryIoU-plant': 0.0, 'min(IoU, B-Iou)-plant': 0.0, 'IoU-curtain': 71.82813693466854, 'BoundaryIoU-curtain': 0.0, 'min(IoU, B-Iou)-curtain': 0.0, 'IoU-chair': 51.58591854213256, 'BoundaryIoU-chair': 0.0, 'min(IoU, B-Iou)-chair': 0.0, 'IoU-car': 73.45956795205252, 'BoundaryIoU-car': 0.0, 'min(IoU, B-Iou)-car': 0.0, 'IoU-water': 25.530251594631277, 'BoundaryIoU-water': 0.0, 'min(IoU, B-Iou)-water': 0.0, 'IoU-painting': 62.105369948655174, 'BoundaryIoU-painting': 0.0, 'min(IoU, B-Iou)-painting': 0.0, 'IoU-sofa': 50.51727331450814, 'BoundaryIoU-sofa': 0.0, 'min(IoU, B-Iou)-sofa': 0.0, 'IoU-shelf': 35.4520778861796, 'BoundaryIoU-shelf': 0.0, 'min(IoU, B-Iou)-shelf': 0.0, 'IoU-house': 24.127403078296858, 'BoundaryIoU-house': 0.0, 'min(IoU, B-Iou)-house': 0.0, 'IoU-sea': 48.38636466296709, 'BoundaryIoU-sea': 0.0, 'min(IoU, B-Iou)-sea': 0.0, 'IoU-mirror': 63.883159764135975, 'BoundaryIoU-mirror': 0.0, 'min(IoU, B-Iou)-mirror': 0.0, 'IoU-rug': 53.535244510310484, 'BoundaryIoU-rug': 0.0, 'min(IoU, B-Iou)-rug': 0.0, 'IoU-field': 19.593244206113678, 'BoundaryIoU-field': 0.0, 'min(IoU, B-Iou)-field': 0.0, 'IoU-armchair': 36.49122884381805, 'BoundaryIoU-armchair': 0.0, 'min(IoU, B-Iou)-armchair': 0.0, 'IoU-seat': 55.011218394554064, 'BoundaryIoU-seat': 0.0, 'min(IoU, B-Iou)-seat': 0.0, 'IoU-fence': 32.59863303431214, 'BoundaryIoU-fence': 0.0, 'min(IoU, B-Iou)-fence': 0.0, 'IoU-desk': 35.51932418255468, 'BoundaryIoU-desk': 0.0, 'min(IoU, B-Iou)-desk': 0.0, 'IoU-rock': 33.425903084494394, 'BoundaryIoU-rock': 0.0, 'min(IoU, B-Iou)-rock': 0.0, 'IoU-wardrobe': 32.634319172154534, 'BoundaryIoU-wardrobe': 0.0, 'min(IoU, B-Iou)-wardrobe': 0.0, 'IoU-lamp': 52.67003717854708, 'BoundaryIoU-lamp': 0.0, 'min(IoU, B-Iou)-lamp': 0.0, 'IoU-bathtub': 70.99120549468995, 'BoundaryIoU-bathtub': 0.0, 'min(IoU, B-Iou)-bathtub': 0.0, 'IoU-railing': 18.889843258676056, 'BoundaryIoU-railing': 0.0, 'min(IoU, B-Iou)-railing': 0.0, 'IoU-cushion': 12.932288569915817, 'BoundaryIoU-cushion': 0.0, 'min(IoU, B-Iou)-cushion': 0.0, 'IoU-base': 0.0021652754771725835, 'BoundaryIoU-base': 0.0, 'min(IoU, B-Iou)-base': 0.0, 'IoU-box': 22.37456576161382, 'BoundaryIoU-box': 0.0, 'min(IoU, B-Iou)-box': 0.0, 'IoU-column': 39.24797952979336, 'BoundaryIoU-column': 0.0, 'min(IoU, B-Iou)-column': 0.0, 'IoU-signboard': 24.58717946223904, 'BoundaryIoU-signboard': 0.0, 'min(IoU, B-Iou)-signboard': 0.0, 'IoU-chest of drawers': 29.62527020614752, 'BoundaryIoU-chest of drawers': 0.0, 'min(IoU, B-Iou)-chest of drawers': 0.0, 'IoU-counter': 22.751522014231863, 'BoundaryIoU-counter': 0.0, 'min(IoU, B-Iou)-counter': 0.0, 'IoU-sand': 38.18911792314837, 'BoundaryIoU-sand': 0.0, 'min(IoU, B-Iou)-sand': 0.0, 'IoU-sink': 64.85881538868877, 'BoundaryIoU-sink': 0.0, 'min(IoU, B-Iou)-sink': 0.0, 'IoU-skyscraper': 28.854210981832345, 'BoundaryIoU-skyscraper': 0.0, 'min(IoU, B-Iou)-skyscraper': 0.0, 'IoU-fireplace': 63.05626857332567, 'BoundaryIoU-fireplace': 0.0, 'min(IoU, B-Iou)-fireplace': 0.0, 'IoU-refrigerator': 61.60946184826782, 'BoundaryIoU-refrigerator': 0.0, 'min(IoU, B-Iou)-refrigerator': 0.0, 'IoU-grandstand': 54.976873063297695, 'BoundaryIoU-grandstand': 0.0, 'min(IoU, B-Iou)-grandstand': 0.0, 'IoU-path': 16.641143308034927, 'BoundaryIoU-path': 0.0, 'min(IoU, B-Iou)-path': 0.0, 'IoU-stairs': 17.141752892956756, 'BoundaryIoU-stairs': 0.0, 'min(IoU, B-Iou)-stairs': 0.0, 'IoU-runway': 24.98767472990469, 'BoundaryIoU-runway': 0.0, 'min(IoU, B-Iou)-runway': 0.0, 'IoU-case': 0.0, 'BoundaryIoU-case': 0.0, 'min(IoU, B-Iou)-case': 0.0, 'IoU-pool table': 79.4801752734445, 'BoundaryIoU-pool table': 0.0, 'min(IoU, B-Iou)-pool table': 0.0, 'IoU-pillow': 0.6212466349140608, 'BoundaryIoU-pillow': 0.0, 'min(IoU, B-Iou)-pillow': 0.0, 'IoU-screen door': 0.46664896992667576, 'BoundaryIoU-screen door': 0.0, 'min(IoU, B-Iou)-screen door': 0.0, 'IoU-stairway': 6.5207310080031915, 'BoundaryIoU-stairway': 0.0, 'min(IoU, B-Iou)-stairway': 0.0, 'IoU-river': 16.01412071774056, 'BoundaryIoU-river': 0.0, 'min(IoU, B-Iou)-river': 0.0, 'IoU-bridge': 54.02961382059909, 'BoundaryIoU-bridge': 0.0, 'min(IoU, B-Iou)-bridge': 0.0, 'IoU-bookcase': 16.562811651669588, 'BoundaryIoU-bookcase': 0.0, 'min(IoU, B-Iou)-bookcase': 0.0, 'IoU-blind': 47.18701124794473, 'BoundaryIoU-blind': 0.0, 'min(IoU, B-Iou)-blind': 0.0, 'IoU-coffee table': 53.06245542569664, 'BoundaryIoU-coffee table': 0.0, 'min(IoU, B-Iou)-coffee table': 0.0, 'IoU-toilet': 80.26519869016514, 'BoundaryIoU-toilet': 0.0, 'min(IoU, B-Iou)-toilet': 0.0, 'IoU-flower': 31.25654312455052, 'BoundaryIoU-flower': 0.0, 'min(IoU, B-Iou)-flower': 0.0, 'IoU-book': 37.79027707674058, 'BoundaryIoU-book': 0.0, 'min(IoU, B-Iou)-book': 0.0, 'IoU-hill': 4.234180779596927, 'BoundaryIoU-hill': 0.0, 'min(IoU, B-Iou)-hill': 0.0, 'IoU-bench': 47.1125541658322, 'BoundaryIoU-bench': 0.0, 'min(IoU, B-Iou)-bench': 0.0, 'IoU-countertop': 41.25193201377492, 'BoundaryIoU-countertop': 0.0, 'min(IoU, B-Iou)-countertop': 0.0, 'IoU-stove': 21.28887244830501, 'BoundaryIoU-stove': 0.0, 'min(IoU, B-Iou)-stove': 0.0, 'IoU-palm': 36.816846742893105, 'BoundaryIoU-palm': 0.0, 'min(IoU, B-Iou)-palm': 0.0, 'IoU-kitchen island': 32.42563187071315, 'BoundaryIoU-kitchen island': 0.0, 'min(IoU, B-Iou)-kitchen island': 0.0, 'IoU-computer': 29.464279516801135, 'BoundaryIoU-computer': 0.0, 'min(IoU, B-Iou)-computer': 0.0, 'IoU-swivel chair': 7.0655545257954895, 'BoundaryIoU-swivel chair': 0.0, 'min(IoU, B-Iou)-swivel chair': 0.0, 'IoU-boat': 80.72058922133452, 'BoundaryIoU-boat': 0.0, 'min(IoU, B-Iou)-boat': 0.0, 'IoU-bar': 37.8211068785458, 'BoundaryIoU-bar': 0.0, 'min(IoU, B-Iou)-bar': 0.0, 'IoU-arcade machine': 82.55993992598023, 'BoundaryIoU-arcade machine': 0.0, 'min(IoU, B-Iou)-arcade machine': 0.0, 'IoU-hovel': 0.6871698480085556, 'BoundaryIoU-hovel': 0.0, 'min(IoU, B-Iou)-hovel': 0.0, 'IoU-bus': 70.37749595669226, 'BoundaryIoU-bus': 0.0, 'min(IoU, B-Iou)-bus': 0.0, 'IoU-towel': 52.950648287256875, 'BoundaryIoU-towel': 0.0, 'min(IoU, B-Iou)-towel': 0.0, 'IoU-light': 27.91664518999395, 'BoundaryIoU-light': 0.0, 'min(IoU, B-Iou)-light': 0.0, 'IoU-truck': 16.171961870216233, 'BoundaryIoU-truck': 0.0, 'min(IoU, B-Iou)-truck': 0.0, 'IoU-tower': 19.18360695400753, 'BoundaryIoU-tower': 0.0, 'min(IoU, B-Iou)-tower': 0.0, 'IoU-chandelier': 61.367403586826, 'BoundaryIoU-chandelier': 0.0, 'min(IoU, B-Iou)-chandelier': 0.0, 'IoU-awning': 27.65144688094523, 'BoundaryIoU-awning': 0.0, 'min(IoU, B-Iou)-awning': 0.0, 'IoU-streetlight': 17.866922439576864, 'BoundaryIoU-streetlight': 0.0, 'min(IoU, B-Iou)-streetlight': 0.0, 'IoU-booth': 2.045909536219201, 'BoundaryIoU-booth': 0.0, 'min(IoU, B-Iou)-booth': 0.0, 'IoU-television receiver': 65.82937518643446, 'BoundaryIoU-television receiver': 0.0, 'min(IoU, B-Iou)-television receiver': 0.0, 'IoU-airplane': 23.23698458017418, 'BoundaryIoU-airplane': 0.0, 'min(IoU, B-Iou)-airplane': 0.0, 'IoU-dirt track': 1.5206396350950122, 'BoundaryIoU-dirt track': 0.0, 'min(IoU, B-Iou)-dirt track': 0.0, 'IoU-apparel': 27.421152435931813, 'BoundaryIoU-apparel': 0.0, 'min(IoU, B-Iou)-apparel': 0.0, 'IoU-pole': 18.24778208728991, 'BoundaryIoU-pole': 0.0, 'min(IoU, B-Iou)-pole': 0.0, 'IoU-land': 6.629741987805245, 'BoundaryIoU-land': 0.0, 'min(IoU, B-Iou)-land': 0.0, 'IoU-bannister': 6.978392886766477, 'BoundaryIoU-bannister': 0.0, 'min(IoU, B-Iou)-bannister': 0.0, 'IoU-escalator': 61.84600399732868, 'BoundaryIoU-escalator': 0.0, 'min(IoU, B-Iou)-escalator': 0.0, 'IoU-ottoman': 1.4907487981283614, 'BoundaryIoU-ottoman': 0.0, 'min(IoU, B-Iou)-ottoman': 0.0, 'IoU-bottle': 34.607977920921066, 'BoundaryIoU-bottle': 0.0, 'min(IoU, B-Iou)-bottle': 0.0, 'IoU-buffet': 0.0, 'BoundaryIoU-buffet': 0.0, 'min(IoU, B-Iou)-buffet': 0.0, 'IoU-poster': 21.707365622596186, 'BoundaryIoU-poster': 0.0, 'min(IoU, B-Iou)-poster': 0.0, 'IoU-stage': 12.849389416553594, 'BoundaryIoU-stage': 0.0, 'min(IoU, B-Iou)-stage': 0.0, 'IoU-van': 35.78622008231206, 'BoundaryIoU-van': 0.0, 'min(IoU, B-Iou)-van': 0.0, 'IoU-ship': 76.13541223642574, 'BoundaryIoU-ship': 0.0, 'min(IoU, B-Iou)-ship': 0.0, 'IoU-fountain': 57.66462082334927, 'BoundaryIoU-fountain': 0.0, 'min(IoU, B-Iou)-fountain': 0.0, 'IoU-conveyer belt': 66.83525127012302, 'BoundaryIoU-conveyer belt': 0.0, 'min(IoU, B-Iou)-conveyer belt': 0.0, 'IoU-canopy': 1.6158420492599617, 'BoundaryIoU-canopy': 0.0, 'min(IoU, B-Iou)-canopy': 0.0, 'IoU-washer': 84.39702391912701, 'BoundaryIoU-washer': 0.0, 'min(IoU, B-Iou)-washer': 0.0, 'IoU-plaything': 8.850194823800528, 'BoundaryIoU-plaything': 0.0, 'min(IoU, B-Iou)-plaything': 0.0, 'IoU-swimming pool': 29.015103543704118, 'BoundaryIoU-swimming pool': 0.0, 'min(IoU, B-Iou)-swimming pool': 0.0, 'IoU-stool': 20.93838674752507, 'BoundaryIoU-stool': 0.0, 'min(IoU, B-Iou)-stool': 0.0, 'IoU-barrel': 11.931600895962704, 'BoundaryIoU-barrel': 0.0, 'min(IoU, B-Iou)-barrel': 0.0, 'IoU-basket': 39.15975864207974, 'BoundaryIoU-basket': 0.0, 'min(IoU, B-Iou)-basket': 0.0, 'IoU-waterfall': 43.80351653071695, 'BoundaryIoU-waterfall': 0.0, 'min(IoU, B-Iou)-waterfall': 0.0, 'IoU-tent': 85.57210540239376, 'BoundaryIoU-tent': 0.0, 'min(IoU, B-Iou)-tent': 0.0, 'IoU-bag': 27.03809758251942, 'BoundaryIoU-bag': 0.0, 'min(IoU, B-Iou)-bag': 0.0, 'IoU-minibike': 72.36794771868817, 'BoundaryIoU-minibike': 0.0, 'min(IoU, B-Iou)-minibike': 0.0, 'IoU-cradle': 55.58706650047658, 'BoundaryIoU-cradle': 0.0, 'min(IoU, B-Iou)-cradle': 0.0, 'IoU-oven': 16.33271305255206, 'BoundaryIoU-oven': 0.0, 'min(IoU, B-Iou)-oven': 0.0, 'IoU-ball': 23.54738284970843, 'BoundaryIoU-ball': 0.0, 'min(IoU, B-Iou)-ball': 0.0, 'IoU-food': 52.82846060120902, 'BoundaryIoU-food': 0.0, 'min(IoU, B-Iou)-food': 0.0, 'IoU-step': 3.591251363025847, 'BoundaryIoU-step': 0.0, 'min(IoU, B-Iou)-step': 0.0, 'IoU-tank': 38.46160545165574, 'BoundaryIoU-tank': 0.0, 'min(IoU, B-Iou)-tank': 0.0, 'IoU-trade name': 5.520448107640255, 'BoundaryIoU-trade name': 0.0, 'min(IoU, B-Iou)-trade name': 0.0, 'IoU-microwave': 85.60446937052035, 'BoundaryIoU-microwave': 0.0, 'min(IoU, B-Iou)-microwave': 0.0, 'IoU-pot': 44.8816646232893, 'BoundaryIoU-pot': 0.0, 'min(IoU, B-Iou)-pot': 0.0, 'IoU-animal': 78.27010928289087, 'BoundaryIoU-animal': 0.0, 'min(IoU, B-Iou)-animal': 0.0, 'IoU-bicycle': 51.1779778005308, 'BoundaryIoU-bicycle': 0.0, 'min(IoU, B-Iou)-bicycle': 0.0, 'IoU-lake': 2.497113742464379, 'BoundaryIoU-lake': 0.0, 'min(IoU, B-Iou)-lake': 0.0, 'IoU-dishwasher': 6.520936461547127, 'BoundaryIoU-dishwasher': 0.0, 'min(IoU, B-Iou)-dishwasher': 0.0, 'IoU-screen': 29.201298882292274, 'BoundaryIoU-screen': 0.0, 'min(IoU, B-Iou)-screen': 0.0, 'IoU-blanket': 0.0, 'BoundaryIoU-blanket': 0.0, 'min(IoU, B-Iou)-blanket': 0.0, 'IoU-sculpture': 52.226683468616244, 'BoundaryIoU-sculpture': 0.0, 'min(IoU, B-Iou)-sculpture': 0.0, 'IoU-hood': 7.8865303436803496, 'BoundaryIoU-hood': 0.0, 'min(IoU, B-Iou)-hood': 0.0, 'IoU-sconce': 14.468004473735292, 'BoundaryIoU-sconce': 0.0, 'min(IoU, B-Iou)-sconce': 0.0, 'IoU-vase': 32.62013168080307, 'BoundaryIoU-vase': 0.0, 'min(IoU, B-Iou)-vase': 0.0, 'IoU-traffic light': 22.896591321492604, 'BoundaryIoU-traffic light': 0.0, 'min(IoU, B-Iou)-traffic light': 0.0, 'IoU-tray': 12.571431846710265, 'BoundaryIoU-tray': 0.0, 'min(IoU, B-Iou)-tray': 0.0, 'IoU-ashcan': 43.23584887124978, 'BoundaryIoU-ashcan': 0.0, 'min(IoU, B-Iou)-ashcan': 0.0, 'IoU-fan': 50.08032558637679, 'BoundaryIoU-fan': 0.0, 'min(IoU, B-Iou)-fan': 0.0, 'IoU-pier': 15.290621517527224, 'BoundaryIoU-pier': 0.0, 'min(IoU, B-Iou)-pier': 0.0, 'IoU-crt screen': 0.23224257148524655, 'BoundaryIoU-crt screen': 0.0, 'min(IoU, B-Iou)-crt screen': 0.0, 'IoU-plate': 54.62306617685104, 'BoundaryIoU-plate': 0.0, 'min(IoU, B-Iou)-plate': 0.0, 'IoU-monitor': 0.19436406121848934, 'BoundaryIoU-monitor': 0.0, 'min(IoU, B-Iou)-monitor': 0.0, 'IoU-bulletin board': 18.133426224779157, 'BoundaryIoU-bulletin board': 0.0, 'min(IoU, B-Iou)-bulletin board': 0.0, 'IoU-shower': 0.5762192433195168, 'BoundaryIoU-shower': 0.0, 'min(IoU, B-Iou)-shower': 0.0, 'IoU-radiator': 58.67226040685106, 'BoundaryIoU-radiator': 0.0, 'min(IoU, B-Iou)-radiator': 0.0, 'IoU-glass': 8.533129570399815, 'BoundaryIoU-glass': 0.0, 'min(IoU, B-Iou)-glass': 0.0, 'IoU-clock': 37.00348878148706, 'BoundaryIoU-clock': 0.0, 'min(IoU, B-Iou)-clock': 0.0, 'IoU-flag': 62.46432210853457, 'BoundaryIoU-flag': 0.0, 'min(IoU, B-Iou)-flag': 0.0, 'mACC': 55.579372548391994, 'pACC': 76.0732008088613, 'ACC-wall': 80.76197927381742, 'ACC-building': 70.8398998365506, 'ACC-sky': 95.47137525767423, 'ACC-floor': 82.82296480943873, 'ACC-tree': 94.05887146780888, 'ACC-ceiling': 91.85533991604474, 'ACC-road': 88.685465794598, 'ACC-bed ': 95.36455710534267, 'ACC-windowpane': 54.860748141549095, 'ACC-grass': 85.47157569335367, 'ACC-cabinet': 75.50363908536994, 'ACC-sidewalk': 85.69867539496468, 'ACC-person': 96.05790319055932, 'ACC-earth': 4.740350320516161, 'ACC-door': 68.08483398920711, 'ACC-table': 55.13711443321454, 'ACC-mountain': 58.96837245469118, 'ACC-plant': 58.43544547950623, 'ACC-curtain': 91.96423945990207, 'ACC-chair': 81.87280391155377, 'ACC-car': 82.01151848372066, 'ACC-water': 29.79732933462284, 'ACC-painting': 79.00189499365112, 'ACC-sofa': 62.87806758494432, 'ACC-shelf': 64.15118062028004, 'ACC-house': 88.78922196005728, 'ACC-sea': 70.42728345179304, 'ACC-mirror': 78.42723033598176, 'ACC-rug': 88.91770129204932, 'ACC-field': 29.675257027112906, 'ACC-armchair': 75.81171666228636, 'ACC-seat': 69.92161617115859, 'ACC-fence': 65.97195277766107, 'ACC-desk': 50.43542587459735, 'ACC-rock': 91.01417555258523, 'ACC-wardrobe': 41.61787254406492, 'ACC-lamp': 65.31704900693103, 'ACC-bathtub': 80.98600684611766, 'ACC-railing': 23.847282214542165, 'ACC-cushion': 13.224753702673459, 'ACC-base': 0.003137258417096266, 'ACC-box': 27.08744403865629, 'ACC-column': 76.33162763902538, 'ACC-signboard': 27.644174686497518, 'ACC-chest of drawers': 59.744208949629915, 'ACC-counter': 31.797885643903623, 'ACC-sand': 91.45510536489977, 'ACC-sink': 74.8726997666537, 'ACC-skyscraper': 95.27930129680676, 'ACC-fireplace': 90.6795440439607, 'ACC-refrigerator': 88.98038939066772, 'ACC-grandstand': 67.76274614641748, 'ACC-path': 23.44416775453339, 'ACC-stairs': 33.65247909541483, 'ACC-runway': 27.46686735605401, 'ACC-case': 0.0, 'ACC-pool table': 80.4022849239516, 'ACC-pillow': 0.6443089707714211, 'ACC-screen door': 0.7293814751668207, 'ACC-stairway': 6.824491698790654, 'ACC-river': 65.59289335546681, 'ACC-bridge': 91.7735985069687, 'ACC-bookcase': 53.62773515666912, 'ACC-blind': 84.7598153094006, 'ACC-coffee table': 90.38669906259747, 'ACC-toilet': 95.14774502662759, 'ACC-flower': 73.13079702731319, 'ACC-book': 53.286088711846055, 'ACC-hill': 8.534985880774135, 'ACC-bench': 63.50425288049707, 'ACC-countertop': 69.29118146543965, 'ACC-stove': 21.78156420759836, 'ACC-palm': 87.18368955946042, 'ACC-kitchen island': 50.77746584976841, 'ACC-computer': 33.36075290295961, 'ACC-swivel chair': 7.34998084670422, 'ACC-boat': 91.19240876592917, 'ACC-bar': 46.46746142333695, 'ACC-arcade machine': 89.66643494335725, 'ACC-hovel': 1.312466575554103, 'ACC-bus': 96.50474843116369, 'ACC-towel': 78.14419308462287, 'ACC-light': 47.70271992953911, 'ACC-truck': 67.65001411233418, 'ACC-tower': 54.33739136344714, 'ACC-chandelier': 82.09136419536885, 'ACC-awning': 40.57627106192122, 'ACC-streetlight': 21.26429459608211, 'ACC-booth': 3.7158158654471674, 'ACC-television receiver': 78.6860741301474, 'ACC-airplane': 69.05426131387486, 'ACC-dirt track': 28.93860982319783, 'ACC-apparel': 51.59025848917847, 'ACC-pole': 28.24926291147208, 'ACC-land': 28.567804595201856, 'ACC-bannister': 20.094148580014046, 'ACC-escalator': 82.50689103955794, 'ACC-ottoman': 1.5194143348382079, 'ACC-bottle': 53.104704264968476, 'ACC-buffet': 0.0, 'ACC-poster': 51.53586761501986, 'ACC-stage': 25.80397451061748, 'ACC-van': 71.15402131341652, 'ACC-ship': 96.2118036776636, 'ACC-fountain': 61.04343058213536, 'ACC-conveyer belt': 75.17459497837733, 'ACC-canopy': 2.675619773834849, 'ACC-washer': 88.57948656959853, 'ACC-plaything': 41.61023542633202, 'ACC-swimming pool': 85.87914757739831, 'ACC-stool': 28.686450537092334, 'ACC-barrel': 74.54773011719195, 'ACC-basket': 51.13342243134483, 'ACC-waterfall': 51.5880636443262, 'ACC-tent': 97.41414712941584, 'ACC-bag': 43.84910733680496, 'ACC-minibike': 79.36124397981492, 'ACC-cradle': 97.2797914164588, 'ACC-oven': 81.59316386034887, 'ACC-ball': 24.292938977038492, 'ACC-food': 86.95215784751973, 'ACC-step': 11.648470082842842, 'ACC-tank': 40.83945377247918, 'ACC-trade name': 6.566616748952899, 'ACC-microwave': 93.60671037910643, 'ACC-pot': 62.7104998728829, 'ACC-animal': 93.3741390317179, 'ACC-bicycle': 87.59961635713664, 'ACC-lake': 6.133381600172744, 'ACC-dishwasher': 6.520936461547127, 'ACC-screen': 77.72382633984213, 'ACC-blanket': 0.0, 'ACC-sculpture': 83.8004878927291, 'ACC-hood': 9.129480928396333, 'ACC-sconce': 17.645467304733078, 'ACC-vase': 59.40368189293862, 'ACC-traffic light': 25.63432383262583, 'ACC-tray': 15.316126869736458, 'ACC-ashcan': 48.55048482642221, 'ACC-fan': 70.95685531842571, 'ACC-pier': 32.64962498086637, 'ACC-crt screen': 1.131339735422136, 'ACC-plate': 76.77706506087183, 'ACC-monitor': 0.2748166430359362, 'ACC-bulletin board': 41.513454241871074, 'ACC-shower': 25.309897346503966, 'ACC-radiator': 87.68139577023634, 'ACC-glass': 27.03182938497286, 'ACC-clock': 43.849800872368675, 'ACC-flag': 81.05050287485267}}

ade150_ours = {'sem_seg': {'mIoU': 35.766785531624045, 'fwIoU': 61.30248575541762, 'IoU-wall': 70.35839163834996, 'BoundaryIoU-wall': 72.87258930807026, 'min(IoU, B-Iou)-wall': 70.35839163834996, 'IoU-building': 51.86283656925812, 'BoundaryIoU-building': 6.989386448295002, 'min(IoU, B-Iou)-building': 6.989386448295002, 'IoU-sky': 92.95028394160421, 'BoundaryIoU-sky': 0.0, 'min(IoU, B-Iou)-sky': 0.0, 'IoU-floor': 64.91629668106361, 'BoundaryIoU-floor': 0.0, 'min(IoU, B-Iou)-floor': 0.0, 'IoU-tree': 73.07309419668505, 'BoundaryIoU-tree': 0.0, 'min(IoU, B-Iou)-tree': 0.0, 'IoU-ceiling': 80.41507190711401, 'BoundaryIoU-ceiling': 0.0, 'min(IoU, B-Iou)-ceiling': 0.0, 'IoU-road': 82.09719562453989, 'BoundaryIoU-road': 0.0, 'min(IoU, B-Iou)-road': 0.0, 'IoU-bed ': 81.89282092855501, 'BoundaryIoU-bed ': 0.0, 'min(IoU, B-Iou)-bed ': 0.0, 'IoU-windowpane': 52.734269902299445, 'BoundaryIoU-windowpane': 0.0, 'min(IoU, B-Iou)-windowpane': 0.0, 'IoU-grass': 65.04333375883127, 'BoundaryIoU-grass': 0.0, 'min(IoU, B-Iou)-grass': 0.0, 'IoU-cabinet': 56.83195841903744, 'BoundaryIoU-cabinet': 0.0, 'min(IoU, B-Iou)-cabinet': 0.0, 'IoU-sidewalk': 62.67635026428924, 'BoundaryIoU-sidewalk': 0.0, 'min(IoU, B-Iou)-sidewalk': 0.0, 'IoU-person': 81.79771774038134, 'BoundaryIoU-person': 0.0, 'min(IoU, B-Iou)-person': 0.0, 'IoU-earth': 1.2228142450315689, 'BoundaryIoU-earth': 0.0, 'min(IoU, B-Iou)-earth': 0.0, 'IoU-door': 43.84027098364581, 'BoundaryIoU-door': 0.0, 'min(IoU, B-Iou)-door': 0.0, 'IoU-table': 43.086303078535956, 'BoundaryIoU-table': 0.0, 'min(IoU, B-Iou)-table': 0.0, 'IoU-mountain': 44.353429501824834, 'BoundaryIoU-mountain': 0.0, 'min(IoU, B-Iou)-mountain': 0.0, 'IoU-plant': 45.42696025679871, 'BoundaryIoU-plant': 0.0, 'min(IoU, B-Iou)-plant': 0.0, 'IoU-curtain': 68.30549301047452, 'BoundaryIoU-curtain': 0.0, 'min(IoU, B-Iou)-curtain': 0.0, 'IoU-chair': 48.78037941989059, 'BoundaryIoU-chair': 0.0, 'min(IoU, B-Iou)-chair': 0.0, 'IoU-car': 74.33742648376703, 'BoundaryIoU-car': 0.0, 'min(IoU, B-Iou)-car': 0.0, 'IoU-water': 36.170689632885484, 'BoundaryIoU-water': 0.0, 'min(IoU, B-Iou)-water': 0.0, 'IoU-painting': 58.654492516741094, 'BoundaryIoU-painting': 0.0, 'min(IoU, B-Iou)-painting': 0.0, 'IoU-sofa': 54.14356990294114, 'BoundaryIoU-sofa': 0.0, 'min(IoU, B-Iou)-sofa': 0.0, 'IoU-shelf': 32.49657389126547, 'BoundaryIoU-shelf': 0.0, 'min(IoU, B-Iou)-shelf': 0.0, 'IoU-house': 17.391053484120107, 'BoundaryIoU-house': 0.0, 'min(IoU, B-Iou)-house': 0.0, 'IoU-sea': 49.31058755171076, 'BoundaryIoU-sea': 0.0, 'min(IoU, B-Iou)-sea': 0.0, 'IoU-mirror': 63.48623065852128, 'BoundaryIoU-mirror': 0.0, 'min(IoU, B-Iou)-mirror': 0.0, 'IoU-rug': 26.914003732081554, 'BoundaryIoU-rug': 0.0, 'min(IoU, B-Iou)-rug': 0.0, 'IoU-field': 16.64790587184182, 'BoundaryIoU-field': 0.0, 'min(IoU, B-Iou)-field': 0.0, 'IoU-armchair': 38.25951546904257, 'BoundaryIoU-armchair': 0.0, 'min(IoU, B-Iou)-armchair': 0.0, 'IoU-seat': 34.780352604907144, 'BoundaryIoU-seat': 0.0, 'min(IoU, B-Iou)-seat': 0.0, 'IoU-fence': 40.18346498556889, 'BoundaryIoU-fence': 0.0, 'min(IoU, B-Iou)-fence': 0.0, 'IoU-desk': 30.810215399672757, 'BoundaryIoU-desk': 0.0, 'min(IoU, B-Iou)-desk': 0.0, 'IoU-rock': 28.284366217600105, 'BoundaryIoU-rock': 0.0, 'min(IoU, B-Iou)-rock': 0.0, 'IoU-wardrobe': 32.79744085489753, 'BoundaryIoU-wardrobe': 0.0, 'min(IoU, B-Iou)-wardrobe': 0.0, 'IoU-lamp': 52.43054091387111, 'BoundaryIoU-lamp': 0.0, 'min(IoU, B-Iou)-lamp': 0.0, 'IoU-bathtub': 67.78474709824653, 'BoundaryIoU-bathtub': 0.0, 'min(IoU, B-Iou)-bathtub': 0.0, 'IoU-railing': 24.464910737625008, 'BoundaryIoU-railing': 0.0, 'min(IoU, B-Iou)-railing': 0.0, 'IoU-cushion': 0.10175850879428343, 'BoundaryIoU-cushion': 0.0, 'min(IoU, B-Iou)-cushion': 0.0, 'IoU-base': 0.3586477390175172, 'BoundaryIoU-base': 0.0, 'min(IoU, B-Iou)-base': 0.0, 'IoU-box': 19.373815021652366, 'BoundaryIoU-box': 0.0, 'min(IoU, B-Iou)-box': 0.0, 'IoU-column': 34.18178895725344, 'BoundaryIoU-column': 0.0, 'min(IoU, B-Iou)-column': 0.0, 'IoU-signboard': 24.818628349900656, 'BoundaryIoU-signboard': 0.0, 'min(IoU, B-Iou)-signboard': 0.0, 'IoU-chest of drawers': 21.83855615987857, 'BoundaryIoU-chest of drawers': 0.0, 'min(IoU, B-Iou)-chest of drawers': 0.0, 'IoU-counter': 18.23803529060251, 'BoundaryIoU-counter': 0.0, 'min(IoU, B-Iou)-counter': 0.0, 'IoU-sand': 27.842498310538843, 'BoundaryIoU-sand': 0.0, 'min(IoU, B-Iou)-sand': 0.0, 'IoU-sink': 61.77202711792952, 'BoundaryIoU-sink': 0.0, 'min(IoU, B-Iou)-sink': 0.0, 'IoU-skyscraper': 30.394787605791564, 'BoundaryIoU-skyscraper': 0.0, 'min(IoU, B-Iou)-skyscraper': 0.0, 'IoU-fireplace': 61.871175115949626, 'BoundaryIoU-fireplace': 0.0, 'min(IoU, B-Iou)-fireplace': 0.0, 'IoU-refrigerator': 55.63199725144457, 'BoundaryIoU-refrigerator': 0.0, 'min(IoU, B-Iou)-refrigerator': 0.0, 'IoU-grandstand': 55.714412111368475, 'BoundaryIoU-grandstand': 0.0, 'min(IoU, B-Iou)-grandstand': 0.0, 'IoU-path': 19.226718513643647, 'BoundaryIoU-path': 0.0, 'min(IoU, B-Iou)-path': 0.0, 'IoU-stairs': 30.1358254886617, 'BoundaryIoU-stairs': 0.0, 'min(IoU, B-Iou)-stairs': 0.0, 'IoU-runway': 56.73179123275889, 'BoundaryIoU-runway': 0.0, 'min(IoU, B-Iou)-runway': 0.0, 'IoU-case': 0.0, 'BoundaryIoU-case': 0.0, 'min(IoU, B-Iou)-case': 0.0, 'IoU-pool table': 88.4161362458677, 'BoundaryIoU-pool table': 0.0, 'min(IoU, B-Iou)-pool table': 0.0, 'IoU-pillow': 2.5612041676275132, 'BoundaryIoU-pillow': 0.0, 'min(IoU, B-Iou)-pillow': 0.0, 'IoU-screen door': 0.5717147549868768, 'BoundaryIoU-screen door': 0.0, 'min(IoU, B-Iou)-screen door': 0.0, 'IoU-stairway': 9.480955149461533, 'BoundaryIoU-stairway': 0.0, 'min(IoU, B-Iou)-stairway': 0.0, 'IoU-river': 19.56740396360103, 'BoundaryIoU-river': 0.0, 'min(IoU, B-Iou)-river': 0.0, 'IoU-bridge': 51.99416246942854, 'BoundaryIoU-bridge': 0.0, 'min(IoU, B-Iou)-bridge': 0.0, 'IoU-bookcase': 14.671670420057383, 'BoundaryIoU-bookcase': 0.0, 'min(IoU, B-Iou)-bookcase': 0.0, 'IoU-blind': 45.207923072937604, 'BoundaryIoU-blind': 0.0, 'min(IoU, B-Iou)-blind': 0.0, 'IoU-coffee table': 53.40682326051499, 'BoundaryIoU-coffee table': 0.0, 'min(IoU, B-Iou)-coffee table': 0.0, 'IoU-toilet': 75.8654291865388, 'BoundaryIoU-toilet': 0.0, 'min(IoU, B-Iou)-toilet': 0.0, 'IoU-flower': 26.16339748850422, 'BoundaryIoU-flower': 0.0, 'min(IoU, B-Iou)-flower': 0.0, 'IoU-book': 39.215256491749834, 'BoundaryIoU-book': 0.0, 'min(IoU, B-Iou)-book': 0.0, 'IoU-hill': 4.377235315443701, 'BoundaryIoU-hill': 0.0, 'min(IoU, B-Iou)-hill': 0.0, 'IoU-bench': 58.66959257303767, 'BoundaryIoU-bench': 0.0, 'min(IoU, B-Iou)-bench': 0.0, 'IoU-countertop': 34.70154072926035, 'BoundaryIoU-countertop': 0.0, 'min(IoU, B-Iou)-countertop': 0.0, 'IoU-stove': 39.16994346555625, 'BoundaryIoU-stove': 0.0, 'min(IoU, B-Iou)-stove': 0.0, 'IoU-palm': 28.44237206588389, 'BoundaryIoU-palm': 0.0, 'min(IoU, B-Iou)-palm': 0.0, 'IoU-kitchen island': 21.315834496235084, 'BoundaryIoU-kitchen island': 0.0, 'min(IoU, B-Iou)-kitchen island': 0.0, 'IoU-computer': 31.672759745432288, 'BoundaryIoU-computer': 0.0, 'min(IoU, B-Iou)-computer': 0.0, 'IoU-swivel chair': 31.436991855862832, 'BoundaryIoU-swivel chair': 0.0, 'min(IoU, B-Iou)-swivel chair': 0.0, 'IoU-boat': 50.260448741634846, 'BoundaryIoU-boat': 0.0, 'min(IoU, B-Iou)-boat': 0.0, 'IoU-bar': 47.566665894400295, 'BoundaryIoU-bar': 0.0, 'min(IoU, B-Iou)-bar': 0.0, 'IoU-arcade machine': 83.8650412543443, 'BoundaryIoU-arcade machine': 0.0, 'min(IoU, B-Iou)-arcade machine': 0.0, 'IoU-hovel': 6.207019242890686, 'BoundaryIoU-hovel': 0.0, 'min(IoU, B-Iou)-hovel': 0.0, 'IoU-bus': 71.40651953610792, 'BoundaryIoU-bus': 0.0, 'min(IoU, B-Iou)-bus': 0.0, 'IoU-towel': 44.639715647332025, 'BoundaryIoU-towel': 0.0, 'min(IoU, B-Iou)-towel': 0.0, 'IoU-light': 27.672500611653856, 'BoundaryIoU-light': 0.0, 'min(IoU, B-Iou)-light': 0.0, 'IoU-truck': 23.063443817243208, 'BoundaryIoU-truck': 0.0, 'min(IoU, B-Iou)-truck': 0.0, 'IoU-tower': 12.072487764350631, 'BoundaryIoU-tower': 0.0, 'min(IoU, B-Iou)-tower': 0.0, 'IoU-chandelier': 58.292850599812574, 'BoundaryIoU-chandelier': 0.0, 'min(IoU, B-Iou)-chandelier': 0.0, 'IoU-awning': 9.62852107925451, 'BoundaryIoU-awning': 0.0, 'min(IoU, B-Iou)-awning': 0.0, 'IoU-streetlight': 13.316587815360077, 'BoundaryIoU-streetlight': 0.0, 'min(IoU, B-Iou)-streetlight': 0.0, 'IoU-booth': 6.5547253854810155, 'BoundaryIoU-booth': 0.0, 'min(IoU, B-Iou)-booth': 0.0, 'IoU-television receiver': 50.93992668937158, 'BoundaryIoU-television receiver': 0.0, 'min(IoU, B-Iou)-television receiver': 0.0, 'IoU-airplane': 19.767874039012824, 'BoundaryIoU-airplane': 0.0, 'min(IoU, B-Iou)-airplane': 0.0, 'IoU-dirt track': 0.9687859177231942, 'BoundaryIoU-dirt track': 0.0, 'min(IoU, B-Iou)-dirt track': 0.0, 'IoU-apparel': 17.076119188272365, 'BoundaryIoU-apparel': 0.0, 'min(IoU, B-Iou)-apparel': 0.0, 'IoU-pole': 15.097159699201567, 'BoundaryIoU-pole': 0.0, 'min(IoU, B-Iou)-pole': 0.0, 'IoU-land': 7.442278129617376, 'BoundaryIoU-land': 0.0, 'min(IoU, B-Iou)-land': 0.0, 'IoU-bannister': 6.3095873071163435, 'BoundaryIoU-bannister': 0.0, 'min(IoU, B-Iou)-bannister': 0.0, 'IoU-escalator': 62.156785548865216, 'BoundaryIoU-escalator': 0.0, 'min(IoU, B-Iou)-escalator': 0.0, 'IoU-ottoman': 26.959354075348912, 'BoundaryIoU-ottoman': 0.0, 'min(IoU, B-Iou)-ottoman': 0.0, 'IoU-bottle': 27.325987194636035, 'BoundaryIoU-bottle': 0.0, 'min(IoU, B-Iou)-bottle': 0.0, 'IoU-buffet': 0.0, 'BoundaryIoU-buffet': 0.0, 'min(IoU, B-Iou)-buffet': 0.0, 'IoU-poster': 16.113158170748275, 'BoundaryIoU-poster': 0.0, 'min(IoU, B-Iou)-poster': 0.0, 'IoU-stage': 12.034448455951084, 'BoundaryIoU-stage': 0.0, 'min(IoU, B-Iou)-stage': 0.0, 'IoU-van': 24.93439079648271, 'BoundaryIoU-van': 0.0, 'min(IoU, B-Iou)-van': 0.0, 'IoU-ship': 43.9516981649646, 'BoundaryIoU-ship': 0.0, 'min(IoU, B-Iou)-ship': 0.0, 'IoU-fountain': 64.29743527409748, 'BoundaryIoU-fountain': 0.0, 'min(IoU, B-Iou)-fountain': 0.0, 'IoU-conveyer belt': 80.66938287125038, 'BoundaryIoU-conveyer belt': 0.0, 'min(IoU, B-Iou)-conveyer belt': 0.0, 'IoU-canopy': 0.06653184941521599, 'BoundaryIoU-canopy': 0.0, 'min(IoU, B-Iou)-canopy': 0.0, 'IoU-washer': 81.82019824187212, 'BoundaryIoU-washer': 0.0, 'min(IoU, B-Iou)-washer': 0.0, 'IoU-plaything': 10.755338950539223, 'BoundaryIoU-plaything': 0.0, 'min(IoU, B-Iou)-plaything': 0.0, 'IoU-swimming pool': 26.381081402382065, 'BoundaryIoU-swimming pool': 0.0, 'min(IoU, B-Iou)-swimming pool': 0.0, 'IoU-stool': 26.02534074973598, 'BoundaryIoU-stool': 0.0, 'min(IoU, B-Iou)-stool': 0.0, 'IoU-barrel': 2.1895191328275843, 'BoundaryIoU-barrel': 0.0, 'min(IoU, B-Iou)-barrel': 0.0, 'IoU-basket': 40.86663719299416, 'BoundaryIoU-basket': 0.0, 'min(IoU, B-Iou)-basket': 0.0, 'IoU-waterfall': 37.33493752527096, 'BoundaryIoU-waterfall': 0.0, 'min(IoU, B-Iou)-waterfall': 0.0, 'IoU-tent': 78.988259285804, 'BoundaryIoU-tent': 0.0, 'min(IoU, B-Iou)-tent': 0.0, 'IoU-bag': 24.419289173080468, 'BoundaryIoU-bag': 0.0, 'min(IoU, B-Iou)-bag': 0.0, 'IoU-minibike': 67.55456683156241, 'BoundaryIoU-minibike': 0.0, 'min(IoU, B-Iou)-minibike': 0.0, 'IoU-cradle': 54.9831920153409, 'BoundaryIoU-cradle': 0.0, 'min(IoU, B-Iou)-cradle': 0.0, 'IoU-oven': 17.87021544799926, 'BoundaryIoU-oven': 0.0, 'min(IoU, B-Iou)-oven': 0.0, 'IoU-ball': 16.678706065599673, 'BoundaryIoU-ball': 0.0, 'min(IoU, B-Iou)-ball': 0.0, 'IoU-food': 50.27572748703546, 'BoundaryIoU-food': 0.0, 'min(IoU, B-Iou)-food': 0.0, 'IoU-step': 2.576589099705739, 'BoundaryIoU-step': 0.0, 'min(IoU, B-Iou)-step': 0.0, 'IoU-tank': 2.4227756164427894, 'BoundaryIoU-tank': 0.0, 'min(IoU, B-Iou)-tank': 0.0, 'IoU-trade name': 2.2193637275312663, 'BoundaryIoU-trade name': 0.0, 'min(IoU, B-Iou)-trade name': 0.0, 'IoU-microwave': 74.79215818879061, 'BoundaryIoU-microwave': 0.0, 'min(IoU, B-Iou)-microwave': 0.0, 'IoU-pot': 40.56484782012613, 'BoundaryIoU-pot': 0.0, 'min(IoU, B-Iou)-pot': 0.0, 'IoU-animal': 48.20707567937097, 'BoundaryIoU-animal': 0.0, 'min(IoU, B-Iou)-animal': 0.0, 'IoU-bicycle': 44.98615365340499, 'BoundaryIoU-bicycle': 0.0, 'min(IoU, B-Iou)-bicycle': 0.0, 'IoU-lake': 2.4998991551835115, 'BoundaryIoU-lake': 0.0, 'min(IoU, B-Iou)-lake': 0.0, 'IoU-dishwasher': 7.921179375595921, 'BoundaryIoU-dishwasher': 0.0, 'min(IoU, B-Iou)-dishwasher': 0.0, 'IoU-screen': 22.881753789415832, 'BoundaryIoU-screen': 0.0, 'min(IoU, B-Iou)-screen': 0.0, 'IoU-blanket': 0.6727236619998014, 'BoundaryIoU-blanket': 0.0, 'min(IoU, B-Iou)-blanket': 0.0, 'IoU-sculpture': 35.992303277858426, 'BoundaryIoU-sculpture': 0.0, 'min(IoU, B-Iou)-sculpture': 0.0, 'IoU-hood': 6.31261334339108, 'BoundaryIoU-hood': 0.0, 'min(IoU, B-Iou)-hood': 0.0, 'IoU-sconce': 14.324906205430546, 'BoundaryIoU-sconce': 0.0, 'min(IoU, B-Iou)-sconce': 0.0, 'IoU-vase': 27.648980329022553, 'BoundaryIoU-vase': 0.0, 'min(IoU, B-Iou)-vase': 0.0, 'IoU-traffic light': 23.22792146314271, 'BoundaryIoU-traffic light': 0.0, 'min(IoU, B-Iou)-traffic light': 0.0, 'IoU-tray': 15.941044497070923, 'BoundaryIoU-tray': 0.0, 'min(IoU, B-Iou)-tray': 0.0, 'IoU-ashcan': 41.029622261578396, 'BoundaryIoU-ashcan': 0.0, 'min(IoU, B-Iou)-ashcan': 0.0, 'IoU-fan': 42.81658814584266, 'BoundaryIoU-fan': 0.0, 'min(IoU, B-Iou)-fan': 0.0, 'IoU-pier': 16.446779015267968, 'BoundaryIoU-pier': 0.0, 'min(IoU, B-Iou)-pier': 0.0, 'IoU-crt screen': 0.13018480492813142, 'BoundaryIoU-crt screen': 0.0, 'min(IoU, B-Iou)-crt screen': 0.0, 'IoU-plate': 54.76241286100441, 'BoundaryIoU-plate': 0.0, 'min(IoU, B-Iou)-plate': 0.0, 'IoU-monitor': 2.750248272227964, 'BoundaryIoU-monitor': 0.0, 'min(IoU, B-Iou)-monitor': 0.0, 'IoU-bulletin board': 22.441389053487196, 'BoundaryIoU-bulletin board': 0.0, 'min(IoU, B-Iou)-bulletin board': 0.0, 'IoU-shower': 0.5479281290549232, 'BoundaryIoU-shower': 0.0, 'min(IoU, B-Iou)-shower': 0.0, 'IoU-radiator': 52.088040815355704, 'BoundaryIoU-radiator': 0.0, 'min(IoU, B-Iou)-radiator': 0.0, 'IoU-glass': 15.064860320380077, 'BoundaryIoU-glass': 0.0, 'min(IoU, B-Iou)-glass': 0.0, 'IoU-clock': 30.146047982970924, 'BoundaryIoU-clock': 0.0, 'min(IoU, B-Iou)-clock': 0.0, 'IoU-flag': 60.64682916534768, 'BoundaryIoU-flag': 0.0, 'min(IoU, B-Iou)-flag': 0.0, 'mACC': 57.287449324915684, 'pACC': 72.61554774924336, 'ACC-wall': 76.54319578448437, 'ACC-building': 53.60126923725662, 'ACC-sky': 95.63728104319426, 'ACC-floor': 67.99743648542976, 'ACC-tree': 92.58699017563343, 'ACC-ceiling': 93.3021382732753, 'ACC-road': 88.58023726479381, 'ACC-bed ': 96.10430403817493, 'ACC-windowpane': 66.07607288567169, 'ACC-grass': 93.18261716222051, 'ACC-cabinet': 67.04481685583983, 'ACC-sidewalk': 83.85614848165388, 'ACC-person': 92.65708135441206, 'ACC-earth': 1.2420347047093918, 'ACC-door': 64.76432121123945, 'ACC-table': 47.607095879697106, 'ACC-mountain': 50.90837745216989, 'ACC-plant': 58.65786394917652, 'ACC-curtain': 93.10093746410257, 'ACC-chair': 73.20917278813121, 'ACC-car': 84.82041814012562, 'ACC-water': 43.54679563076955, 'ACC-painting': 85.7576581268292, 'ACC-sofa': 70.30327136412178, 'ACC-shelf': 49.37723271024716, 'ACC-house': 88.68867008624157, 'ACC-sea': 68.22536012302633, 'ACC-mirror': 81.97481851778235, 'ACC-rug': 91.01744374788086, 'ACC-field': 17.597220732946592, 'ACC-armchair': 75.88329030326038, 'ACC-seat': 36.84892809392414, 'ACC-fence': 65.37376525742698, 'ACC-desk': 54.6319792993233, 'ACC-rock': 92.7591137534574, 'ACC-wardrobe': 57.853949185441266, 'ACC-lamp': 65.4594344943002, 'ACC-bathtub': 78.26688563418364, 'ACC-railing': 46.46891255012877, 'ACC-cushion': 0.10250524572785295, 'ACC-base': 0.4094122234310627, 'ACC-box': 24.067524778789448, 'ACC-column': 70.98486902300994, 'ACC-signboard': 29.848625692621756, 'ACC-chest of drawers': 73.43034591466632, 'ACC-counter': 27.95987480600347, 'ACC-sand': 91.98667709287939, 'ACC-sink': 76.77350254472043, 'ACC-skyscraper': 93.36014095313877, 'ACC-fireplace': 91.69728226631904, 'ACC-refrigerator': 91.03314968894858, 'ACC-grandstand': 73.07838968122718, 'ACC-path': 21.82912752479544, 'ACC-stairs': 59.48174114326276, 'ACC-runway': 74.24502276650642, 'ACC-case': 0.0, 'ACC-pool table': 90.43149125156413, 'ACC-pillow': 3.1998583567921166, 'ACC-screen door': 1.049215732877945, 'ACC-stairway': 10.240825528480176, 'ACC-river': 63.590624459214354, 'ACC-bridge': 91.80357696753141, 'ACC-bookcase': 51.987304099853745, 'ACC-blind': 82.66673870132473, 'ACC-coffee table': 87.39759985553167, 'ACC-toilet': 95.96800779738271, 'ACC-flower': 76.44278809574419, 'ACC-book': 60.940542052254735, 'ACC-hill': 7.073397675649049, 'ACC-bench': 80.43931350666587, 'ACC-countertop': 63.51930213441547, 'ACC-stove': 46.210775111908255, 'ACC-palm': 90.0233284012485, 'ACC-kitchen island': 30.43093148766119, 'ACC-computer': 39.58189522493434, 'ACC-swivel chair': 70.12240112914463, 'ACC-boat': 57.065651239081916, 'ACC-bar': 66.22284151313413, 'ACC-arcade machine': 98.21314143018591, 'ACC-hovel': 26.08790381682413, 'ACC-bus': 96.69038717250467, 'ACC-towel': 80.42045751863171, 'ACC-light': 45.0905677432813, 'ACC-truck': 67.4620378210556, 'ACC-tower': 58.10289216061078, 'ACC-chandelier': 87.31055768131819, 'ACC-awning': 51.11944547501589, 'ACC-streetlight': 15.656532197239944, 'ACC-booth': 21.588443591123113, 'ACC-television receiver': 68.836704132177, 'ACC-airplane': 72.02942696874025, 'ACC-dirt track': 31.685873141076204, 'ACC-apparel': 44.72962870670322, 'ACC-pole': 25.849170154264073, 'ACC-land': 15.489392103873511, 'ACC-bannister': 16.565822350693253, 'ACC-escalator': 86.32470385415762, 'ACC-ottoman': 29.153489927518848, 'ACC-bottle': 39.28464200496184, 'ACC-buffet': 0.0, 'ACC-poster': 75.0616749967961, 'ACC-stage': 34.76179565144694, 'ACC-van': 82.62184745039573, 'ACC-ship': 77.98945375878853, 'ACC-fountain': 73.21394825167752, 'ACC-conveyer belt': 91.6727984681254, 'ACC-canopy': 0.1266949127572938, 'ACC-washer': 97.92491377699247, 'ACC-plaything': 54.530588133590754, 'ACC-swimming pool': 87.61063098708871, 'ACC-stool': 51.00825997595688, 'ACC-barrel': 81.93196040505177, 'ACC-basket': 54.111946865185864, 'ACC-waterfall': 53.19650209134469, 'ACC-tent': 97.56016317292863, 'ACC-bag': 36.1638672482725, 'ACC-minibike': 75.87049547698494, 'ACC-cradle': 97.71553803672795, 'ACC-oven': 74.3480675535809, 'ACC-ball': 17.70888260390202, 'ACC-food': 88.3086963008605, 'ACC-step': 8.666051891571888, 'ACC-tank': 2.422977249767088, 'ACC-trade name': 4.259189929101248, 'ACC-microwave': 96.01655100562947, 'ACC-pot': 62.68568177140713, 'ACC-animal': 88.88415247271519, 'ACC-bicycle': 90.7916993635016, 'ACC-lake': 4.526286374779306, 'ACC-dishwasher': 8.110492950254391, 'ACC-screen': 82.62322689773873, 'ACC-blanket': 0.7529817103243239, 'ACC-sculpture': 87.28040734131207, 'ACC-hood': 6.5537014091155354, 'ACC-sconce': 17.776800762072252, 'ACC-vase': 67.29421037872415, 'ACC-traffic light': 31.839296543359612, 'ACC-tray': 17.86218069580034, 'ACC-ashcan': 65.29657698205204, 'ACC-fan': 73.1474737174351, 'ACC-pier': 24.26839959367129, 'ACC-crt screen': 0.5421537356444702, 'ACC-plate': 82.11613891676727, 'ACC-monitor': 4.750652033118031, 'ACC-bulletin board': 41.763910608260076, 'ACC-shower': 28.09413131900058, 'ACC-radiator': 90.70176801014729, 'ACC-glass': 23.54378028509323, 'ACC-clock': 38.67532713825147, 'ACC-flag': 82.53010966919749}}

# PASCAL VOC 2012 20 classes

voc_catseg = {'sem_seg': {'mIoU': 96.96483474962407, 'fwIoU': 97.5168583906477, 'IoU-aeroplane': 99.94055469124294, 'BoundaryIoU-aeroplane': 80.95770390627608, 'min(IoU, B-Iou)-aeroplane': 80.95770390627608, 'IoU-bicycle': 95.96559132492534, 'BoundaryIoU-bicycle': 2.7442540128836987, 'min(IoU, B-Iou)-bicycle': 2.7442540128836987, 'IoU-bird': 99.80242129131202, 'BoundaryIoU-bird': 3.1165739081586112, 'min(IoU, B-Iou)-bird': 3.1165739081586112, 'IoU-boat': 99.26578452310763, 'BoundaryIoU-boat': 4.195115651578439, 'min(IoU, B-Iou)-boat': 4.195115651578439, 'IoU-bottle': 97.46710473990386, 'BoundaryIoU-bottle': 4.392670948027923, 'min(IoU, B-Iou)-bottle': 4.392670948027923, 'IoU-bus': 99.60264683677255, 'BoundaryIoU-bus': 4.3054969555868885, 'min(IoU, B-Iou)-bus': 4.3054969555868885, 'IoU-car': 98.82664202412265, 'BoundaryIoU-car': 7.339242760745238, 'min(IoU, B-Iou)-car': 7.339242760745238, 'IoU-cat': 99.6096432693018, 'BoundaryIoU-cat': 5.746570884072207, 'min(IoU, B-Iou)-cat': 5.746570884072207, 'IoU-chair': 78.14238767203902, 'BoundaryIoU-chair': 5.641580672777624, 'min(IoU, B-Iou)-chair': 5.641580672777624, 'IoU-cow': 99.64815163581575, 'BoundaryIoU-cow': 3.302094282496616, 'min(IoU, B-Iou)-cow': 3.302094282496616, 'IoU-diningtable': 93.34249695259969, 'BoundaryIoU-diningtable': 13.04706808743464, 'min(IoU, B-Iou)-diningtable': 13.04706808743464, 'IoU-dog': 99.0275472384096, 'BoundaryIoU-dog': 5.467809054121968, 'min(IoU, B-Iou)-dog': 5.467809054121968, 'IoU-horse': 99.22381436571868, 'BoundaryIoU-horse': 0.0, 'min(IoU, B-Iou)-horse': 0.0, 'IoU-motorbike': 98.30696803551355, 'BoundaryIoU-motorbike': 0.0, 'min(IoU, B-Iou)-motorbike': 0.0, 'IoU-person': 98.71182754331139, 'BoundaryIoU-person': 0.0, 'min(IoU, B-Iou)-person': 0.0, 'IoU-pottedplant': 97.54933489197992, 'BoundaryIoU-pottedplant': 0.0, 'min(IoU, B-Iou)-pottedplant': 0.0, 'IoU-sheep': 99.51211039394062, 'BoundaryIoU-sheep': 0.0, 'min(IoU, B-Iou)-sheep': 0.0, 'IoU-sofa': 88.38900576692471, 'BoundaryIoU-sofa': 0.0, 'min(IoU, B-Iou)-sofa': 0.0, 'IoU-train': 99.87903361554572, 'BoundaryIoU-train': 0.0, 'min(IoU, B-Iou)-train': 0.0, 'IoU-tvmonitor': 97.08362817999372, 'BoundaryIoU-tvmonitor': 0.0, 'min(IoU, B-Iou)-tvmonitor': 0.0, 'mACC': 98.34173998979374, 'pACC': 98.69269301370224, 'ACC-aeroplane': 99.97406192805641, 'ACC-bicycle': 97.48682700221569, 'ACC-bird': 99.85719497092084, 'ACC-boat': 99.49616395025258, 'ACC-bottle': 98.83951155623156, 'ACC-bus': 99.90638203720094, 'ACC-car': 99.52023874522952, 'ACC-cat': 99.71170877009784, 'ACC-chair': 85.35322934093529, 'ACC-cow': 99.86969318238505, 'ACC-diningtable': 95.07953573610263, 'ACC-dog': 99.11643696980906, 'ACC-horse': 99.80283405698168, 'ACC-motorbike': 99.02467303589648, 'ACC-person': 99.51671675401663, 'ACC-pottedplant': 99.6322582421944, 'ACC-sheep': 99.5970105623692, 'ACC-sofa': 95.92864523379421, 'ACC-train': 99.92794089316038, 'ACC-tvmonitor': 99.19373682802465}}

voc_ours = {'sem_seg': {'mIoU': 96.85222009390942, 'fwIoU': 97.39219500333108, 'IoU-aeroplane': 99.92611927736132, 'BoundaryIoU-aeroplane': 82.52070177082035, 'min(IoU, B-Iou)-aeroplane': 82.52070177082035, 'IoU-bicycle': 95.98950850023625, 'BoundaryIoU-bicycle': 3.208146436597672, 'min(IoU, B-Iou)-bicycle': 3.208146436597672, 'IoU-bird': 99.83274300542668, 'BoundaryIoU-bird': 2.324262195313715, 'min(IoU, B-Iou)-bird': 2.324262195313715, 'IoU-boat': 99.18303093012084, 'BoundaryIoU-boat': 6.768312745473952, 'min(IoU, B-Iou)-boat': 6.768312745473952, 'IoU-bottle': 97.30042681806114, 'BoundaryIoU-bottle': 3.4168539399636004, 'min(IoU, B-Iou)-bottle': 3.4168539399636004, 'IoU-bus': 99.57955387608715, 'BoundaryIoU-bus': 4.914508559832785, 'min(IoU, B-Iou)-bus': 4.914508559832785, 'IoU-car': 98.65682156657515, 'BoundaryIoU-car': 9.55127771306137, 'min(IoU, B-Iou)-car': 9.55127771306137, 'IoU-cat': 99.50359868254937, 'BoundaryIoU-cat': 8.059095741411044, 'min(IoU, B-Iou)-cat': 8.059095741411044, 'IoU-chair': 77.6864837903556, 'BoundaryIoU-chair': 5.1869720225098535, 'min(IoU, B-Iou)-chair': 5.1869720225098535, 'IoU-cow': 99.6554485373967, 'BoundaryIoU-cow': 4.076946600441976, 'min(IoU, B-Iou)-cow': 4.076946600441976, 'IoU-diningtable': 92.91852524483777, 'BoundaryIoU-diningtable': 12.758744926686258, 'min(IoU, B-Iou)-diningtable': 12.758744926686258, 'IoU-dog': 99.37747511715612, 'BoundaryIoU-dog': 5.428509357379706, 'min(IoU, B-Iou)-dog': 5.428509357379706, 'IoU-horse': 98.77628114440256, 'BoundaryIoU-horse': 0.0, 'min(IoU, B-Iou)-horse': 0.0, 'IoU-motorbike': 97.94628426955248, 'BoundaryIoU-motorbike': 0.0, 'min(IoU, B-Iou)-motorbike': 0.0, 'IoU-person': 98.42733816854852, 'BoundaryIoU-person': 0.0, 'min(IoU, B-Iou)-person': 0.0, 'IoU-pottedplant': 97.62934752793669, 'BoundaryIoU-pottedplant': 0.0, 'min(IoU, B-Iou)-pottedplant': 0.0, 'IoU-sheep': 99.44974452055325, 'BoundaryIoU-sheep': 0.0, 'min(IoU, B-Iou)-sheep': 0.0, 'IoU-sofa': 88.41804981203259, 'BoundaryIoU-sofa': 0.0, 'min(IoU, B-Iou)-sofa': 0.0, 'IoU-train': 99.8724807292878, 'BoundaryIoU-train': 0.0, 'min(IoU, B-Iou)-train': 0.0, 'IoU-tvmonitor': 96.91514035971045, 'BoundaryIoU-tvmonitor': 0.0, 'min(IoU, B-Iou)-tvmonitor': 0.0, 'mACC': 98.4015571021151, 'pACC': 98.62248557976741, 'ACC-aeroplane': 99.97343816680727, 'ACC-bicycle': 97.97191810904278, 'ACC-bird': 99.93875137379553, 'ACC-boat': 99.50639638216798, 'ACC-bottle': 99.1688421705536, 'ACC-bus': 99.94991612571144, 'ACC-car': 99.49179814184347, 'ACC-cat': 99.6056424884604, 'ACC-chair': 87.22477087001991, 'ACC-cow': 99.87670399926655, 'ACC-diningtable': 94.44213282136312, 'ACC-dog': 99.50645450719044, 'ACC-horse': 99.92236756591849, 'ACC-motorbike': 99.35697059641963, 'ACC-person': 99.03391044494137, 'ACC-pottedplant': 99.46345343530743, 'ACC-sheep': 99.64269546074229, 'ACC-sofa': 94.62603129710986, 'ACC-train': 99.92270997357747, 'ACC-tvmonitor': 99.40623811206297}}

voc_ours2 = {'sem_seg': {'mIoU': 96.62588668190753, 'fwIoU': 97.18243263594655, 'IoU-aeroplane': 99.88252018875747, 'BoundaryIoU-aeroplane': 83.69056633056488, 'min(IoU, B-Iou)-aeroplane': 83.69056633056488, 'IoU-bicycle': 95.48015377268847, 'BoundaryIoU-bicycle': 2.901020026089477, 'min(IoU, B-Iou)-bicycle': 2.901020026089477, 'IoU-bird': 99.82757050935449, 'BoundaryIoU-bird': 1.1287456194644312, 'min(IoU, B-Iou)-bird': 1.1287456194644312, 'IoU-boat': 99.13309351188077, 'BoundaryIoU-boat': 8.74177517001097, 'min(IoU, B-Iou)-boat': 8.74177517001097, 'IoU-bottle': 96.92180031457768, 'BoundaryIoU-bottle': 4.5091958610949066, 'min(IoU, B-Iou)-bottle': 4.5091958610949066, 'IoU-bus': 99.57879357956028, 'BoundaryIoU-bus': 4.5220172993854275, 'min(IoU, B-Iou)-bus': 4.5220172993854275, 'IoU-car': 98.60759196923166, 'BoundaryIoU-car': 6.562235921861919, 'min(IoU, B-Iou)-car': 6.562235921861919, 'IoU-cat': 99.75083291401003, 'BoundaryIoU-cat': 7.728409574182699, 'min(IoU, B-Iou)-cat': 7.728409574182699, 'IoU-chair': 76.71642332582044, 'BoundaryIoU-chair': 4.5233116180870505, 'min(IoU, B-Iou)-chair': 4.5233116180870505, 'IoU-cow': 99.6295150332952, 'BoundaryIoU-cow': 3.5504998888234476, 'min(IoU, B-Iou)-cow': 3.5504998888234476, 'IoU-diningtable': 92.04166427668838, 'BoundaryIoU-diningtable': 15.045439599971367, 'min(IoU, B-Iou)-diningtable': 15.045439599971367, 'IoU-dog': 99.23616891024821, 'BoundaryIoU-dog': 5.636558712212807, 'min(IoU, B-Iou)-dog': 5.636558712212807, 'IoU-horse': 98.7880190146084, 'BoundaryIoU-horse': 0.0, 'min(IoU, B-Iou)-horse': 0.0, 'IoU-motorbike': 97.62974292533967, 'BoundaryIoU-motorbike': 0.0, 'min(IoU, B-Iou)-motorbike': 0.0, 'IoU-person': 98.03459119496856, 'BoundaryIoU-person': 0.0, 'min(IoU, B-Iou)-person': 0.0, 'IoU-pottedplant': 96.95652071000315, 'BoundaryIoU-pottedplant': 0.0, 'min(IoU, B-Iou)-pottedplant': 0.0, 'IoU-sheep': 99.5814426658644, 'BoundaryIoU-sheep': 0.0, 'min(IoU, B-Iou)-sheep': 0.0, 'IoU-sofa': 87.89742189775086, 'BoundaryIoU-sofa': 0.0, 'min(IoU, B-Iou)-sofa': 0.0, 'IoU-train': 99.84073850409973, 'BoundaryIoU-train': 0.0, 'min(IoU, B-Iou)-train': 0.0, 'IoU-tvmonitor': 96.98312841940306, 'BoundaryIoU-tvmonitor': 0.0, 'min(IoU, B-Iou)-tvmonitor': 0.0, 'mACC': 98.19770221329911, 'pACC': 98.51721575076247, 'ACC-aeroplane': 99.9226536051061, 'ACC-bicycle': 97.41116607634741, 'ACC-bird': 99.86834798327978, 'ACC-boat': 99.40815020616867, 'ACC-bottle': 98.88603100151579, 'ACC-bus': 99.91647287324058, 'ACC-car': 99.49533234598245, 'ACC-cat': 99.86470780819484, 'ACC-chair': 84.00784601973425, 'ACC-cow': 99.84967190725229, 'ACC-diningtable': 93.54250807225762, 'ACC-dog': 99.39815933969346, 'ACC-horse': 99.8747131366115, 'ACC-motorbike': 99.36972451535108, 'ACC-person': 99.00507883959403, 'ACC-pottedplant': 99.53789279112755, 'ACC-sheep': 99.66887502877941, 'ACC-sofa': 95.68856372162271, 'ACC-train': 99.89726984272794, 'ACC-tvmonitor': 99.34087915139462}}

voc_ours_llmutate = {'sem_seg': {'mIoU': 96.4036309226248, 'fwIoU': 97.04654809055818, 'IoU-aeroplane': 99.91849384522038, 'BoundaryIoU-aeroplane': 81.39847741376714, 'min(IoU, B-Iou)-aeroplane': 81.39847741376714, 'IoU-bicycle': 95.55992297604382, 'BoundaryIoU-bicycle': 2.658084612968596, 'min(IoU, B-Iou)-bicycle': 2.658084612968596, 'IoU-bird': 99.82087502734954, 'BoundaryIoU-bird': 2.6141727748462817, 'min(IoU, B-Iou)-bird': 2.6141727748462817, 'IoU-boat': 98.96411476552906, 'BoundaryIoU-boat': 5.332234042323184, 'min(IoU, B-Iou)-boat': 5.332234042323184, 'IoU-bottle': 96.84796664585748, 'BoundaryIoU-bottle': 3.4900588920613935, 'min(IoU, B-Iou)-bottle': 3.4900588920613935, 'IoU-bus': 99.60463269745708, 'BoundaryIoU-bus': 4.323893137345384, 'min(IoU, B-Iou)-bus': 4.323893137345384, 'IoU-car': 98.7516021235155, 'BoundaryIoU-car': 8.165400988591772, 'min(IoU, B-Iou)-car': 8.165400988591772, 'IoU-cat': 99.74974389760791, 'BoundaryIoU-cat': 5.6615366105451095, 'min(IoU, B-Iou)-cat': 5.6615366105451095, 'IoU-chair': 72.3419466130782, 'BoundaryIoU-chair': 4.8915891344870595, 'min(IoU, B-Iou)-chair': 4.8915891344870595, 'IoU-cow': 99.83745062217409, 'BoundaryIoU-cow': 3.3693021989295504, 'min(IoU, B-Iou)-cow': 3.3693021989295504, 'IoU-diningtable': 92.21024391815781, 'BoundaryIoU-diningtable': 13.572383311139621, 'min(IoU, B-Iou)-diningtable': 13.572383311139621, 'IoU-dog': 99.40585102531317, 'BoundaryIoU-dog': 5.33944023010315, 'min(IoU, B-Iou)-dog': 5.33944023010315, 'IoU-horse': 98.99720631304974, 'BoundaryIoU-horse': 0.0, 'min(IoU, B-Iou)-horse': 0.0, 'IoU-motorbike': 97.60868953356666, 'BoundaryIoU-motorbike': 0.0, 'min(IoU, B-Iou)-motorbike': 0.0, 'IoU-person': 98.180734254436, 'BoundaryIoU-person': 0.0, 'min(IoU, B-Iou)-person': 0.0, 'IoU-pottedplant': 97.00410518965249, 'BoundaryIoU-pottedplant': 0.0, 'min(IoU, B-Iou)-pottedplant': 0.0, 'IoU-sheep': 99.66019848330355, 'BoundaryIoU-sheep': 0.0, 'min(IoU, B-Iou)-sheep': 0.0, 'IoU-sofa': 86.45421015495307, 'BoundaryIoU-sofa': 0.0, 'min(IoU, B-Iou)-sofa': 0.0, 'IoU-train': 99.77979115463458, 'BoundaryIoU-train': 0.0, 'min(IoU, B-Iou)-train': 0.0, 'IoU-tvmonitor': 97.37483921159533, 'BoundaryIoU-tvmonitor': 0.0, 'min(IoU, B-Iou)-tvmonitor': 0.0, 'mACC': 98.0263625413835, 'pACC': 98.4377216030221, 'ACC-aeroplane': 99.98055944106834, 'ACC-bicycle': 97.62363179825722, 'ACC-bird': 99.85807791773259, 'ACC-boat': 99.55563069225369, 'ACC-bottle': 99.45394288723406, 'ACC-bus': 99.96123360007702, 'ACC-car': 99.35783232511116, 'ACC-cat': 99.90978772585187, 'ACC-chair': 76.96288844017552, 'ACC-cow': 99.90811785183178, 'ACC-diningtable': 93.89611658958025, 'ACC-dog': 99.52957548572428, 'ACC-horse': 99.88587918636969, 'ACC-motorbike': 99.18351729895186, 'ACC-person': 98.89200632972202, 'ACC-pottedplant': 99.35620892267865, 'ACC-sheep': 99.9227030145307, 'ACC-sofa': 97.93805247417895, 'ACC-train': 99.88389910194041, 'ACC-tvmonitor': 99.46758974440019}}

avg_score = {'sem_seg': {'mIoU': 96.19098356044947, 'fwIoU': 96.7901831404673, 'IoU-aeroplane': 99.31713072984043, 'BoundaryIoU-aeroplane': 81.62961897495848, 'min(IoU, B-Iou)-aeroplane': 81.62961897495848, 'IoU-bicycle': 95.25540989168101, 'BoundaryIoU-bicycle': 2.841893275167352, 'min(IoU, B-Iou)-bicycle': 2.841893275167352, 'IoU-bird': 99.72135841835254, 'BoundaryIoU-bird': 1.361493676103871, 'min(IoU, B-Iou)-bird': 1.361493676103871, 'IoU-boat': 99.07689805814478, 'BoundaryIoU-boat': 7.331710959919882, 'min(IoU, B-Iou)-boat': 7.331710959919882, 'IoU-bottle': 97.43186366254143, 'BoundaryIoU-bottle': 3.772518984124847, 'min(IoU, B-Iou)-bottle': 3.772518984124847, 'IoU-bus': 99.52754968957414, 'BoundaryIoU-bus': 4.967050325746194, 'min(IoU, B-Iou)-bus': 4.967050325746194, 'IoU-car': 98.18004145854697, 'BoundaryIoU-car': 7.506836957693958, 'min(IoU, B-Iou)-car': 7.506836957693958, 'IoU-cat': 99.26889847171883, 'BoundaryIoU-cat': 6.029384043511066, 'min(IoU, B-Iou)-cat': 6.029384043511066, 'IoU-chair': 73.36351485892392, 'BoundaryIoU-chair': 5.0011824863746845, 'min(IoU, B-Iou)-chair': 5.0011824863746845, 'IoU-cow': 99.38566502474633, 'BoundaryIoU-cow': 3.4098138030834577, 'min(IoU, B-Iou)-cow': 3.4098138030834577, 'IoU-diningtable': 91.3809451153058, 'BoundaryIoU-diningtable': 14.041075724073359, 'min(IoU, B-Iou)-diningtable': 14.041075724073359, 'IoU-dog': 98.90844985246, 'BoundaryIoU-dog': 5.034565593191056, 'min(IoU, B-Iou)-dog': 5.034565593191056, 'IoU-horse': 98.80437277674173, 'BoundaryIoU-horse': 0.0, 'min(IoU, B-Iou)-horse': 0.0, 'IoU-motorbike': 97.50543564075184, 'BoundaryIoU-motorbike': 0.0, 'min(IoU, B-Iou)-motorbike': 0.0, 'IoU-person': 97.86441307177718, 'BoundaryIoU-person': 0.0, 'min(IoU, B-Iou)-person': 0.0, 'IoU-pottedplant': 96.58917150455426, 'BoundaryIoU-pottedplant': 0.0, 'min(IoU, B-Iou)-pottedplant': 0.0, 'IoU-sheep': 98.9389794538179, 'BoundaryIoU-sheep': 0.0, 'min(IoU, B-Iou)-sheep': 0.0, 'IoU-sofa': 86.66250024774577, 'BoundaryIoU-sofa': 0.0, 'min(IoU, B-Iou)-sofa': 0.0, 'IoU-train': 99.67675631278004, 'BoundaryIoU-train': 0.0, 'min(IoU, B-Iou)-train': 0.0, 'IoU-tvmonitor': 96.96031696898409, 'BoundaryIoU-tvmonitor': 0.0, 'min(IoU, B-Iou)-tvmonitor': 0.0, 'mACC': 97.85547011999707, 'pACC': 98.30833968172865, 'ACC-aeroplane': 99.92852735686888, 'ACC-bicycle': 96.72062172366661, 'ACC-bird': 99.77048029983014, 'ACC-boat': 99.3837554952979, 'ACC-bottle': 99.38853467389816, 'ACC-bus': 99.930243624258, 'ACC-car': 99.11625416660405, 'ACC-cat': 99.39240870967082, 'ACC-chair': 78.97850385466228, 'ACC-cow': 99.75994693350914, 'ACC-diningtable': 93.65983070075923, 'ACC-dog': 99.08505282368924, 'ACC-horse': 99.70922849409354, 'ACC-motorbike': 98.56688464273567, 'ACC-person': 99.20458462526183, 'ACC-pottedplant': 99.67251543462378, 'ACC-sheep': 99.2310657308937, 'ACC-sofa': 96.77026702709072, 'ACC-train': 99.83462639113755, 'ACC-tvmonitor': 99.00606969139056}}

# plot the results for pascal voc
import matplotlib.pyplot as plt
import numpy as np

# plot the mIoU
plt.plot([voc_catseg['sem_seg']['mIoU'], voc_ours['sem_seg']['mIoU'], voc_ours2['sem_seg']['mIoU'], voc_ours_llmutate['sem_seg']['mIoU'], avg_score['sem_seg']['mIoU']])
plt.xlabel('Models')
plt.ylabel('mIoU')
plt.title('mIoU by models')
plt.xticks([0, 1, 2, 3, 4], ['CatSeg', 'Ours', 'Ours2', 'Ours_llmutate', 'Average'])
plt.show()

# %%
# Extract class names and mIoU values
classes = ['aeroplane', 'bicycle', 'bird', 'boat', 'bottle', 'bus', 'car', 'cat', 'chair', 'cow',
           'diningtable', 'dog', 'horse', 'motorbike', 'person', 'pottedplant', 'sheep', 'sofa', 
           'train', 'tvmonitor']

catseg_miou = [voc_catseg['sem_seg'][f'IoU-{cls}'] for cls in classes]
ours_miou = [voc_ours['sem_seg'][f'IoU-{cls}'] for cls in classes]
ours2_miou = [voc_ours2['sem_seg'][f'IoU-{cls}'] for cls in classes]
ours_llmutate_miou = [voc_ours_llmutate['sem_seg'][f'IoU-{cls}'] for cls in classes]
avg_score_miou = [avg_score['sem_seg'][f'IoU-{cls}'] for cls in classes]

# Set up the bar width and positions on the x-axis
bar_width = 0.2
x = np.arange(len(classes))

# Create the bar plot
plt.figure(figsize=(16, 8))
plt.bar(x, catseg_miou, width=bar_width, label='CATSeg')
plt.bar(x + bar_width, ours_miou, width=bar_width, label='Ours')
plt.bar(x + 2 * bar_width, ours2_miou, width=bar_width, label='Ours2')
plt.bar(x + 3 * bar_width, ours_llmutate_miou, width=bar_width, label='Ours_LLmutate')
plt.bar(x + 4 * bar_width, avg_score_miou, width=bar_width, label='Average')

# Set labels and title
plt.xlabel('Classes', fontsize=12)
plt.ylabel('Normalized mIoU', fontsize=12)
plt.title('mIoU Comparison for Each Class Across Different Methods', fontsize=14)
plt.xticks(x + bar_width * 2, classes, rotation=45, ha='right')
plt.legend()
plt.tight_layout()

# Show plot
plt.show()

import matplotlib.pyplot as plt
import numpy as np

# Normalize the mIoU values
catseg_miou = np.array(catseg_miou) - 70
ours_miou = np.array(ours_miou) - 70
ours2_miou = np.array(ours2_miou) - 70
ours_llmutate_miou = np.array(ours_llmutate_miou) - 70
avg_score_miou = np.array(avg_score_miou) - 70

# Set up the bar width and positions on the x-axis
bar_width = 0.2
x = np.arange(len(classes))

# Create the bar plot
plt.figure(figsize=(16, 8))
plt.bar(x, catseg_miou, width=bar_width, label='CATSeg')
plt.bar(x + bar_width, ours_miou, width=bar_width, label='Ours')
plt.bar(x + 2 * bar_width, ours2_miou, width=bar_width, label='Ours2')
plt.bar(x + 3 * bar_width, ours_llmutate_miou, width=bar_width, label='Ours_LLmutate')
plt.bar(x + 4 * bar_width, avg_score_miou, width=bar_width, label='Average')

# Set labels and title
plt.xlabel('Classes', fontsize=12)
plt.ylabel('Normalized mIoU', fontsize=12)
plt.title('mIoU Comparison for Each Class Across Different Methods', fontsize=14)
plt.xticks(x + bar_width * 2, classes, rotation=45, ha='right')
plt.legend()
plt.tight_layout()

# Show plot
plt.show()

# %%
# Extract class names and mIoU values
classes = ["wall", "building", "sky", "floor", "tree", "ceiling", "road", "bed ", "windowpane", "grass", "cabinet", "sidewalk", "person", "earth", "door", "table", "mountain", "plant", "curtain", "chair", "car", "water", "painting", "sofa", "shelf", "house", "sea", "mirror", "rug", "field", "armchair", "seat", "fence", "desk", "rock", "wardrobe", "lamp", "bathtub", "railing", "cushion", "base", "box", "column", "signboard", "chest of drawers", "counter", "sand", "sink", "skyscraper", "fireplace", "refrigerator", "grandstand", "path", "stairs", "runway", "case", "pool table", "pillow", "screen door", "stairway", "river", "bridge", "bookcase", "blind", "coffee table", "toilet", "flower", "book", "hill", "bench", "countertop", "stove", "palm", "kitchen island", "computer", "swivel chair", "boat", "bar", "arcade machine", "hovel", "bus", "towel", "light", "truck", "tower", "chandelier", "awning", "streetlight", "booth", "television receiver", "airplane", "dirt track", "apparel", "pole", "land", "bannister", "escalator", "ottoman", "bottle", "buffet", "poster", "stage", "van", "ship", "fountain", "conveyer belt", "canopy", "washer", "plaything", "swimming pool", "stool", "barrel", "basket", "waterfall", "tent", "bag", "minibike", "cradle", "oven", "ball", "food", "step", "tank", "trade name", "microwave", "pot", "animal", "bicycle", "lake", "dishwasher", "screen", "blanket", "sculpture", "hood", "sconce", "vase", "traffic light", "tray", "ashcan", "fan", "pier", "crt screen", "plate", "monitor", "bulletin board", "shower", "radiator", "glass", "clock", "flag"]

ade150_catseg_miou = [ade150_catseg['sem_seg'][f'IoU-{cls}'] for cls in classes]
ade150_ours_miou = [ade150_ours['sem_seg'][f'IoU-{cls}'] for cls in classes]


# Set up the bar width and positions on the x-axis
bar_width = 0.2
x = np.arange(len(classes))

# Create the bar plot
plt.figure(figsize=(16, 8))
plt.bar(x, ade150_catseg_miou, width=bar_width, label='CATSeg')
plt.bar(x + bar_width, ade150_ours_miou, width=bar_width, label='Ours')

# Set labels and title
plt.xlabel('Classes', fontsize=12)
plt.ylabel('Normalized mIoU', fontsize=12)
plt.title('mIoU Comparison for Each Class Across Different Methods', fontsize=14)
plt.xticks(x + bar_width * 2, classes, rotation=45, ha='right')
plt.legend()
plt.tight_layout()

# Show plot
plt.show()

# %%
# worst performing classes if mIoU is less than 10 in catseg
worst_classes = [classes[i] for i in range(len(classes)) if ade150_catseg_miou[i] < 10]

# plot for worst performing classes
worst_classes_miou = [ade150_catseg['sem_seg'][f'IoU-{cls}'] for cls in worst_classes]
worst_classes_ours_miou = [ade150_ours['sem_seg'][f'IoU-{cls}'] for cls in worst_classes]

# Set up the bar width and positions on the x-axis
bar_width = 0.2
x = np.arange(len(worst_classes))

# Create the bar plot
plt.figure(figsize=(16, 8))
plt.bar(x, worst_classes_miou, width=bar_width, label='CATSeg')
plt.bar(x + bar_width, worst_classes_ours_miou, width=bar_width, label='Ours')

# Set labels and title
plt.xlabel('Classes', fontsize=12)
plt.ylabel('Normalized mIoU', fontsize=12)
plt.title('mIoU Comparison for Worst Performing Classes Across Different Methods', fontsize=14)
plt.xticks(x + bar_width * 2, worst_classes, rotation=45, ha='right')
plt.legend()
plt.tight_layout()

# Show plot
plt.show()

# %%
# worst performing classes if mIoU is less than 10 in ours
worst_classes = [classes[i] for i in range(len(classes)) if ade150_ours_miou[i] < 10]

# plot for worst performing classes
worst_classes_miou = [ade150_catseg['sem_seg'][f'IoU-{cls}'] for cls in worst_classes]
worst_classes_ours_miou = [ade150_ours['sem_seg'][f'IoU-{cls}'] for cls in worst_classes]

# Set up the bar width and positions on the x-axis
bar_width = 0.2
x = np.arange(len(worst_classes))

# Create the bar plot
plt.figure(figsize=(16, 8))
plt.bar(x, worst_classes_miou, width=bar_width, label='CATSeg')
plt.bar(x + bar_width, worst_classes_ours_miou, width=bar_width, label='Ours')

# Set labels and title
plt.xlabel('Classes', fontsize=12)
plt.ylabel('Normalized mIoU', fontsize=12)
plt.title('mIoU Comparison for Worst Performing Classes Across Different Methods', fontsize=14)
plt.xticks(x + bar_width * 2, worst_classes, rotation=45, ha='right')
plt.legend()
plt.tight_layout()

# Show plot
plt.show()
